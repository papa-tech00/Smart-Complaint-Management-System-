# %%
import pandas as pd

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
df = pd.read_csv("../data/complaints_clean.csv")

print(df.shape)
print(df.head())
# Out:
# (577, 9)
#    complaint_id      category  \
# 0             1  Water Supply
# 1             2   Road Damage
# 2             3  Street Light
# 3             4  Water Supply
# 4             5  Street Light
#
#                                       complaint_text         area  \
# 0  Irregular water supply timing in Melapudur, wa...    Melapudur
# 1  Deep crack across the road in Cantonment is wi...   Cantonment
# 2  Broken street light glass in Anna Nagar Lake R...   Anna Nagar
# 3  Irregular water supply timing in Golden Rock, ...  Golden Rock
# 4  Street light near Woraiyur bus stop flickers c...     Woraiyur
#
#   date_reported priority       status  \
# 0    2026-03-11     High  In Progress
# 1    2026-02-14   Medium  In Progress
# 2    2025-05-16     High  In Progress
# 3    2025-04-29   Medium     Resolved
# 4    2025-12-05      Low     Resolved
#
#                                           clean_text  \
# 0  irregular water supply timing melapudur water ...
# ...

# %%
print(df.isnull().sum())
# Out:
# complaint_id      0
# category          0
# complaint_text    0
# area              0
# date_reported     0
# priority          0
# status            0
# clean_text        0
# tokens            0
# dtype: int64

# %%
# Input feature
X = df["clean_text"]

# Target label
y = df["category"]

print("Input (X):")
print(X.head())

print("\nTarget (y):")
print(y.head())
# Out:
# Input (X):
# 0    irregular water supply timing melapudur water ...
# 1    deep crack across road cantonment widening eve...
# 2    broken street light glass anna nagar lake road...
# 3    irregular water supply timing golden rock wate...
# 4    street light near woraiyur bus stop flickers c...
# Name: clean_text, dtype: str
#
# Target (y):
# 0    Water Supply
# 1     Road Damage
# 2    Street Light
# 3    Water Supply
# 4    Street Light
# Name: category, dtype: str

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Create TF-IDF Vectorizer
vectorizer = TfidfVectorizer(
    max_features=1000,
    stop_words="english"
)

# Convert text into numerical features
X_features = vectorizer.fit_transform(X)

# Print shape
print("TF-IDF Matrix Shape:", X_features.shape)
# Out:
# TF-IDF Matrix Shape: (577, 248)

# %%
print(vectorizer.get_feature_names_out()[:20])
# Out:
# ['accidents' 'ago' 'animal' 'anna' 'appliances' 'ariyamangalam' 'arrived'
#  'attracting' 'bad' 'bharathi' 'bin' 'blocked' 'blocking' 'booking' 'box'
#  'breaker' 'breeding' 'broken' 'bus' 'bypass']

# %%
from sklearn.preprocessing import LabelEncoder

# Create Label Encoder
label_encoder = LabelEncoder()

# Convert categories into numbers
y_encoded = label_encoder.fit_transform(y)

# Print encoded labels
print("Encoded Labels:")
print(y_encoded[:10])
# Out:
# Encoded Labels:
# [5 3 4 5 4 2 0 5 3 0]

# %%
# Display category to number mapping
mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))

print("Category Mapping:")
print(mapping)
# Out:
# Category Mapping:
# {'Drainage': np.int64(0), 'Electricity': np.int64(1), 'Garbage': np.int64(2), 'Road Damage': np.int64(3), 'Street Light': np.int64(4), 'Water Supply': np.int64(5)}

# %%
print("TF-IDF Matrix Shape :", X_features.shape)
print("Number of Labels    :", len(y_encoded))
print("Number of Classes   :", len(label_encoder.classes_))
print("Classes             :", label_encoder.classes_)
# Out:
# TF-IDF Matrix Shape : (577, 248)
# Number of Labels    : 577
# Number of Classes   : 6
# Classes             : ['Drainage' 'Electricity' 'Garbage' 'Road Damage' 'Street Light'
#  'Water Supply']

# %%
# ✅ Day 1 Verification Check
print("1. Rows in original clean_text vs feature matrix match:", X_features.shape[0] == len(y_encoded))
print("2. No missing values in labels:", pd.isnull(y_encoded).sum() == 0)
print("3. Number of classes matches expected categories:", len(label_encoder.classes_) == 6)
print("4. TF-IDF feature matrix is non-empty:", X_features.shape[1] > 0)
print("5. Sample check — first row has non-zero features:", X_features[0].nnz > 0)

print("\nSummary:")
print("TF-IDF Matrix Shape :", X_features.shape)
print("Number of Labels    :", len(y_encoded))
print("Number of Classes   :", len(label_encoder.classes_))
print("Classes             :", list(label_encoder.classes_))
# Out:
# 1. Rows in original clean_text vs feature matrix match: True
# 2. No missing values in labels: True
# 3. Number of classes matches expected categories: True
# 4. TF-IDF feature matrix is non-empty: True
# 5. Sample check — first row has non-zero features: True
#
# Summary:
# TF-IDF Matrix Shape : (577, 248)
# Number of Labels    : 577
# Number of Classes   : 6
# Classes             : ['Drainage', 'Electricity', 'Garbage', 'Road Damage', 'Street Light', 'Water Supply']

# %%
print("Original dataset rows:", len(df))
print("Rows used in feature engineering:", X_features.shape[0])
print("Difference:", len(df) - X_features.shape[0])
# Out:
# Original dataset rows: 577
# Rows used in feature engineering: 577
# Difference: 0

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import pickle
import scipy.sparse

# %%
# Save the TF-IDF Vectorizer

import pickle

with open("../models/vectorizer.pkl", "wb") as file:
    pickle.dump(vectorizer, file)

print("✅ Vectorizer saved successfully!")
# Out:
# ✅ Vectorizer saved successfully!

# %%
import pandas as pd

df = pd.read_csv("../data/complaints_clean.csv")

print(df.shape)

df.head()
# Out:
# (577, 9)
#    complaint_id      category  \
# 0             1  Water Supply
# 1             2   Road Damage
# 2             3  Street Light
# 3             4  Water Supply
# 4             5  Street Light
#
#                                       complaint_text         area  \
# 0  Irregular water supply timing in Melapudur, wa...    Melapudur
# 1  Deep crack across the road in Cantonment is wi...   Cantonment
# 2  Broken street light glass in Anna Nagar Lake R...   Anna Nagar
# 3  Irregular water supply timing in Golden Rock, ...  Golden Rock
# 4  Street light near Woraiyur bus stop flickers c...     Woraiyur
#
#   date_reported priority       status  \
# 0    2026-03-11     High  In Progress
# 1    2026-02-14   Medium  In Progress
# 2    2025-05-16     High  In Progress
# 3    2025-04-29   Medium     Resolved
# 4    2025-12-05      Low     Resolved
#
#                                           clean_text  \
# 0  irregular water supply timing melapudur water ...
# ...

# %%
print(df.columns)
# Out:
# Index(['complaint_id', 'category', 'complaint_text', 'area', 'date_reported',
#        'priority', 'status', 'clean_text', 'tokens'],
#       dtype='str')

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 577 entries, 0 to 576
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   complaint_id    577 non-null    int64
#  1   category        577 non-null    str
#  2   complaint_text  577 non-null    str
#  3   area            577 non-null    str
#  4   date_reported   577 non-null    str
#  5   priority        577 non-null    str
#  6   status          577 non-null    str
#  7   clean_text      577 non-null    str
#  8   tokens          577 non-null    str
# dtypes: int64(1), str(8)
# memory usage: 40.7 KB
# None

# %%
# Create TF-IDF Vectorizer

vectorizer = TfidfVectorizer(
    max_features=5000,
    stop_words="english",
    ngram_range=(1,2),
    min_df=2,
    max_df=0.95
)

# %%
# Convert clean text into TF-IDF features

X_features = vectorizer.fit_transform(df["clean_text"])

print("TF-IDF Matrix Shape :", X_features.shape)
# Out:
# TF-IDF Matrix Shape : (577, 730)

# %%
feature_names = vectorizer.get_feature_names_out()

print("Total Features :", len(feature_names))
print()
print(feature_names[:20])
# Out:
# Total Features : 730
#
# ['accidents' 'accidents twowheelers' 'ago' 'animal' 'animal lying' 'anna'
#  'anna nagar' 'appliances' 'ariyamangalam' 'ariyamangalam colony'
#  'ariyamangalam cross' 'ariyamangalam main' 'ariyamangalam market'
#  'ariyamangalam nd' 'arrived' 'attracting' 'attracting stray' 'bad'
#  'bad odour' 'bad smell']

# %%
import pickle

with open("../models/vectorizer.pkl", "wb") as file:
    pickle.dump(vectorizer, file)

print("✅ Vectorizer saved successfully!")
# Out:
# ✅ Vectorizer saved successfully!

# %%
import scipy.sparse

scipy.sparse.save_npz(
    "../models/tfidf_matrix.npz",
    X_features
)

print("✅ TF-IDF Matrix saved successfully!")
# Out:
# ✅ TF-IDF Matrix saved successfully!

# %%
import scipy.sparse
import pickle

# Load back what you saved
X = scipy.sparse.load_npz("../models/tfidf_matrix.npz")
with open("../models/vectorizer.pkl", "rb") as f:
    tfidf = pickle.load(f)

print("✅ Matrix shape:", X.shape)
print("✅ Vocabulary size:", len(tfidf.get_feature_names_out()))
print("✅ Sample features:", tfidf.get_feature_names_out()[:10])
# Out:
# ✅ Matrix shape: (577, 730)
# ✅ Vocabulary size: 730
# ✅ Sample features: ['accidents' 'accidents twowheelers' 'ago' 'animal' 'animal lying' 'anna'
#  'anna nagar' 'appliances' 'ariyamangalam' 'ariyamangalam colony']

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import pickle

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_features,
    y_encoded,
    test_size=0.2,
    random_state=42,
    stratify=y_encoded
)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_features,
    y_encoded,
    test_size=0.2,
    random_state=42,
    stratify=y_encoded
)

# %%
print("Training Features :", X_train.shape)
print("Testing Features :", X_test.shape)

print("Training Labels :", len(y_train))
print("Testing Labels :", len(y_test))
# Out:
# Training Features : (461, 730)
# Testing Features : (116, 730)
# Training Labels : 461
# Testing Labels : 116

# %%
model = MultinomialNB()

model.fit(
    X_train,
    y_train
)

print("Model trained successfully!")
# Out:
# Model trained successfully!

# %%
y_pred = model.predict(X_test)

print(y_pred[:10])
# Out:
# [0 4 2 2 2 3 5 0 1 0]

# %%
accuracy = accuracy_score(
    y_test,
    y_pred
)

print("Accuracy :", accuracy)

print("\nClassification Report\n")

print(
    classification_report(
        y_test,
        y_pred
    )
)

print("\nConfusion Matrix\n")

print(
    confusion_matrix(
        y_test,
        y_pred
    )
)
# Out:
# Accuracy : 1.0
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        19
#            2       1.00      1.00      1.00        19
#            3       1.00      1.00      1.00        19
#            4       1.00      1.00      1.00        20
#            5       1.00      1.00      1.00        20
#
#     accuracy                           1.00       116
#    macro avg       1.00      1.00      1.00       116
# weighted avg       1.00      1.00      1.00       116
#
#
# Confusion Matrix
#
# [[19  0  0  0  0  0]
#  [ 0 19  0  0  0  0]
#  [ 0  0 19  0  0  0]
#  [ 0  0  0 19  0  0]
#  [ 0  0  0  0 20  0]
#  [ 0  0  0  0  0 20]]

# %%
with open("../models/naive_bayes_model.pkl","wb") as file:
    pickle.dump(model,file)

print("Naive Bayes Model Saved!")
# Out:
# Naive Bayes Model Saved!

# %%
results = pd.DataFrame({

    "Actual":y_test,

    "Predicted":y_pred

})

results.to_csv(

    "../models/day3_predictions.csv",

    index=False

)

print("Predictions Saved!")
# Out:
# Predictions Saved!

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_model = LogisticRegression(
    max_iter=1000,
    random_state=42
)

log_model.fit(X_train, y_train)

print("✅ Logistic Regression Model Trained Successfully!")
# Out:
# ✅ Logistic Regression Model Trained Successfully!

# %%
log_pred = log_model.predict(X_test)

print(log_pred[:10])
# Out:
# [0 4 2 2 2 3 5 0 1 0]

# %%
log_accuracy = accuracy_score(y_test, log_pred)

print("Logistic Regression Accuracy :", log_accuracy)

print("\nClassification Report\n")
print(classification_report(y_test, log_pred))

print("\nConfusion Matrix\n")
print(confusion_matrix(y_test, log_pred))
# Out:
# Logistic Regression Accuracy : 1.0
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        19
#            2       1.00      1.00      1.00        19
#            3       1.00      1.00      1.00        19
#            4       1.00      1.00      1.00        20
#            5       1.00      1.00      1.00        20
#
#     accuracy                           1.00       116
#    macro avg       1.00      1.00      1.00       116
# weighted avg       1.00      1.00      1.00       116
#
#
# Confusion Matrix
#
# [[19  0  0  0  0  0]
#  [ 0 19  0  0  0  0]
#  [ 0  0 19  0  0  0]
#  [ 0  0  0 19  0  0]
#  [ 0  0  0  0 20  0]
#  [ 0  0  0  0  0 20]]

# %%
with open("../models/logistic_regression_model.pkl", "wb") as file:
    pickle.dump(log_model, file)

print("✅ Logistic Regression Model Saved!")
# Out:
# ✅ Logistic Regression Model Saved!

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

rf_model.fit(X_train, y_train)

print("✅ Random Forest Model Trained Successfully!")
# Out:
# ✅ Random Forest Model Trained Successfully!

# %%
rf_pred = rf_model.predict(X_test)

print(rf_pred[:10])
# Out:
# [0 4 2 2 2 3 5 0 1 0]

# %%
rf_accuracy = accuracy_score(y_test, rf_pred)

print("Random Forest Accuracy :", rf_accuracy)

print("\nClassification Report\n")
print(classification_report(y_test, rf_pred))

print("\nConfusion Matrix\n")
print(confusion_matrix(y_test, rf_pred))
# Out:
# Random Forest Accuracy : 1.0
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        19
#            2       1.00      1.00      1.00        19
#            3       1.00      1.00      1.00        19
#            4       1.00      1.00      1.00        20
#            5       1.00      1.00      1.00        20
#
#     accuracy                           1.00       116
#    macro avg       1.00      1.00      1.00       116
# weighted avg       1.00      1.00      1.00       116
#
#
# Confusion Matrix
#
# [[19  0  0  0  0  0]
#  [ 0 19  0  0  0  0]
#  [ 0  0 19  0  0  0]
#  [ 0  0  0 19  0  0]
#  [ 0  0  0  0 20  0]
#  [ 0  0  0  0  0 20]]

# %%
with open("../models/random_forest_model.pkl", "wb") as file:
    pickle.dump(rf_model, file)

print("✅ Random Forest Model Saved!")
# Out:
# ✅ Random Forest Model Saved!

# %%
comparison = pd.DataFrame({
    "Model": [
        "Naive Bayes",
        "Logistic Regression",
        "Random Forest"
    ],
    "Accuracy": [
        accuracy,
        log_accuracy,
        rf_accuracy
    ]
})

print(comparison)

best_model = comparison.loc[comparison["Accuracy"].idxmax()]

print("\n🏆 Best Model:")
print(best_model)
# Out:
#                  Model  Accuracy
# 0          Naive Bayes       1.0
# 1  Logistic Regression       1.0
# 2        Random Forest       1.0
#
# 🏆 Best Model:
# Model       Naive Bayes
# Accuracy            1.0
# Name: 0, dtype: object

# %%
best_model_name = comparison.loc[comparison["Accuracy"].idxmax(), "Model"]

print("Best Model :", best_model_name)
# Out:
# Best Model : Naive Bayes

# %%
import pickle
import pandas as pd

# 1. Check model loads correctly
with open("../models/naive_bayes_model.pkl", "rb") as f:
    model = pickle.load(f)

print("✅ Model loaded:", model)

# 2. Check predictions file exists and has data
preds = pd.read_csv("../models/day3_predictions.csv")

print(preds.head())
print("Total rows:", len(preds))
# Out:
# ✅ Model loaded: MultinomialNB()
#    Actual  Predicted
# 0       0          0
# 1       4          4
# 2       2          2
# 3       2          2
# 4       2          2
# Total rows: 116

# %% [markdown]
# # Day 4 - Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# %%
# Create Logistic Regression model
log_model = LogisticRegression(max_iter=1000)

# Train model
log_model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# Predict using Logistic Regression
y_pred_log = log_model.predict(X_test)

# %%
accuracy_log = accuracy_score(y_test, y_pred_log)

print("Logistic Regression Accuracy:", accuracy_log)
# Out:
# Logistic Regression Accuracy: 1.0

# %%
print(classification_report(y_test, y_pred_log))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        19
#            2       1.00      1.00      1.00        19
#            3       1.00      1.00      1.00        19
#            4       1.00      1.00      1.00        20
#            5       1.00      1.00      1.00        20
#
#     accuracy                           1.00       116
#    macro avg       1.00      1.00      1.00       116
# weighted avg       1.00      1.00      1.00       116

# %%
import joblib

joblib.dump(log_model, "../models/logistic_regression_model.pkl")

print("✅ Logistic Regression model saved successfully!")
# Out:
# ✅ Logistic Regression model saved successfully!

# %%
import joblib

loaded_log_model = joblib.load("../models/logistic_regression_model.pkl")

print(loaded_log_model)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# # Day 5 - Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# Create Random Forest model
rf_model = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

# Train the model
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred_rf = rf_model.predict(X_test)

# %%
accuracy_rf = accuracy_score(y_test, y_pred_rf)

print("Random Forest Accuracy:", accuracy_rf)
# Out:
# Random Forest Accuracy: 1.0

# %%
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        19
#            2       1.00      1.00      1.00        19
#            3       1.00      1.00      1.00        19
#            4       1.00      1.00      1.00        20
#            5       1.00      1.00      1.00        20
#
#     accuracy                           1.00       116
#    macro avg       1.00      1.00      1.00       116
# weighted avg       1.00      1.00      1.00       116

# %%
import joblib

joblib.dump(rf_model, "../models/random_forest_model.pkl")

print("✅ Random Forest model saved successfully!")
# Out:
# ✅ Random Forest model saved successfully!

# %%
loaded_rf_model = joblib.load("../models/random_forest_model.pkl")

print(loaded_rf_model)
# Out:
# RandomForestClassifier(random_state=42)

# %%
print("========== Model Comparison ==========")
print(f"Naive Bayes          : {accuracy:.4f}")
print(f"Logistic Regression  : {accuracy_log:.4f}")
print(f"Random Forest        : {accuracy_rf:.4f}")
# Out:
# ========== Model Comparison ==========
# Naive Bayes          : 1.0000
# Logistic Regression  : 1.0000
# Random Forest        : 1.0000

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd

# %%
# Train Naive Bayes

nb_model = MultinomialNB()

nb_model.fit(X_train, y_train)

nb_pred = nb_model.predict(X_test)

nb_acc = accuracy_score(y_test, nb_pred)

print("Naive Bayes Accuracy :", nb_acc)
# Out:
# Naive Bayes Accuracy : 1.0

# %%
# Train Logistic Regression

lr_model = LogisticRegression(max_iter=1000)

lr_model.fit(X_train, y_train)

lr_pred = lr_model.predict(X_test)

lr_acc = accuracy_score(y_test, lr_pred)

print("Logistic Regression Accuracy :", lr_acc)
# Out:
# Logistic Regression Accuracy : 1.0

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

rf_model.fit(X_train, y_train)

rf_pred = rf_model.predict(X_test)

rf_acc = accuracy_score(y_test, rf_pred)

print("Random Forest Accuracy :", rf_acc)
# Out:
# Random Forest Accuracy : 1.0

# %%
comparison = pd.DataFrame({
    "Model": [
        "Naive Bayes",
        "Logistic Regression",
        "Random Forest"
    ],
    "Accuracy": [
        nb_acc,
        lr_acc,
        rf_acc
    ]
})

comparison = comparison.sort_values(
    by="Accuracy",
    ascending=False
)

comparison
# Out:
#                  Model  Accuracy
# 0          Naive Bayes       1.0
# 1  Logistic Regression       1.0
# 2        Random Forest       1.0

# %%
best_model = comparison.iloc[0]

print("Best Model :", best_model["Model"])
print("Accuracy :", best_model["Accuracy"])
# Out:
# Best Model : Naive Bayes
# Accuracy : 1.0

# %%
from sklearn.metrics import classification_report

print(classification_report(
    y_test,
    rf_pred
))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        19
#            2       1.00      1.00      1.00        19
#            3       1.00      1.00      1.00        19
#            4       1.00      1.00      1.00        20
#            5       1.00      1.00      1.00        20
#
#     accuracy                           1.00       116
#    macro avg       1.00      1.00      1.00       116
# weighted avg       1.00      1.00      1.00       116

# %%
comparison.to_csv(
    "../models/model_comparison.csv",
    index=False
)

print("Comparison table saved successfully.")
# Out:
# Comparison table saved successfully.

# %%
import joblib

joblib.dump(
    rf_model,
    "../models/best_model.pkl"
)

print("Best model saved successfully.")
# Out:
# Best model saved successfully.

# %%
import pandas as pd

print("\nTraining Labels:")
print(pd.Series(y_train).value_counts())

print("\nTesting Labels:")
print(pd.Series(y_test).value_counts())
# Out:
# Training Labels:
# 4    78
# 5    77
# 2    77
# 0    77
# 1    76
# 3    76
# Name: count, dtype: int64
#
# Testing Labels:
# 4    20
# 5    20
# 0    19
# 2    19
# 3    19
# 1    19
# Name: count, dtype: int64
